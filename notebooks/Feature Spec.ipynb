# %%
# mixture of libs for web scraping, parsing and pandas
from bs4 import BeautifulSoup
import datetime as dt
from functools import reduce
import io
import json
import numpy as np
import os
import pandas as pd
import requests
import seaborn as sns
import sqlite3
from urllib.request import Request, urlopen
import warnings

from epl.query import create_and_query, create_conn, get_table_columns, query_creator, query_db, table_exists
from epl.features_parse import calc_rolling_avg, create_base_feat_cols, create_col_map, get_feats_raw_data, get_new_matches, handle_feats, merge_home_away, process_feature_data, split_home_away_feats
from epl.features_parse import FEATURE_KEY_COLS, FEATURE_ID_COLS

pd.options.display.max_columns = None
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Get New Matches

# %% [markdown]
# First step is to check if there are any new matches in the matches table that don't have corresponding features in the features table

# %%
df_new_matches = get_new_matches()
# Out:
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='features'
# Features table doesn't exist
# Running query: SELECT Date, HomeTeam, AwayTeam, Country, Div, Season FROM matches

# %%
print("Found {} new matches for features to be calculated".format(len(df_new_matches)/2))
df_new_matches.tail()
# Out:
# Found 189561.0 new matches for features to be calculated
#              Date                Team Location  Country  Div Season
# 189523 2020-12-06       Werder Bremen     Home  germany   D1   2021
# 189512 2020-12-06           West Brom     Home  england   E0   2021
# 379076 2020-12-06              Wolves     Away  england   E0   2021
# 189527 2020-12-06  Wurzburger Kickers     Home  germany   D2   2021
# 189557 2020-12-06            Zaragoza     Home    spain  SP2   2021

# %% [markdown]
# ## 2. Define Features We Wish to Calc

# %% [markdown]
# To 'automate' the calc of features we need the following:
#  - A naming convention
#  - A mapping from feature name to calc methodology

# %% [markdown]
# Can be done in the following way:
#  - feats: A dict of base col feature to raw data cols
#  - streak_length: Averaging period
#  - avg_type: Can be 'Avg' or 'Exp'

# %%
# define feats
# we define the new base col name,the required cols and how to convert to t and opp equiv cols
feats = {'GF': {'Home': 'FTHG', 'Away': 'FTAG'},
         'GA': {'Home': 'FTAG', 'Away': 'FTHG'},
         
         'GFH': {'Home': 'FTHG'},
         'GAH': {'Home': 'FTAG'},
         'GFA': {'Away': 'FTAG'},
         'GAA': {'Away': 'FTHG'},
         
         'SF': {'Home': 'HS', 'Away': 'AS'},
         'SA': {'Home': 'AS', 'Away': 'HS'},
         
         'SFH': {'Home': 'HS'},
         'SAH': {'Home': 'AS'},
         'SFA': {'Away': 'AS'},
         'SAA': {'Away': 'HS'},
         
         'STF': {'Home': 'HST', 'Away': 'AST'},
         'STA': {'Home': 'AST', 'Away': 'HST'},
         
         'STFH': {'Home': 'HST'},
         'STAH': {'Home': 'AST'},
         'STFA': {'Away': 'AST'},
         'STAA': {'Away': 'HST'},
         
         'PPG': {'Home': 'FTR', 'Away': 'FTR'},
         'PPGH': {'Home': 'FTR'},
         'PPGA': {'Away': 'FTR'},
        }

# handle streak lengths by iterating over avg function so for now its an int
streak_length = 3

# avg type is string for avg - for now only 2 types
avg_type = 'Avg'

# %% [markdown]
# When we want to bulk create can then create a list of these configs like so:

# %%
feat_list = [{'feat_type': 'avg',
              'feat_dict': feats,
              'streak': x,
              'avg_type': 'Avg'} for x in [3,5,10,20,40]]

# %% [markdown]
# ## 3. Compute a Subset of Features

# %% [markdown]
# Let's demonstrate by operating on the first element of the feat_list

# %%
feat_desc = feat_list[0]

# %%
feats = feat_desc['feat_dict']
streak_length = feat_desc['streak']
avg_type = feat_desc['avg_type']

# %% [markdown]
# ### 3i. Get Relevant Raw Match Data

# %%
# get the raw data required to calc the features
df_raw = get_feats_raw_data(feats)
df_raw.tail()
# Out:
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='matches'
# Running query: SELECT Date, HomeTeam, AwayTeam, HS, AST, FTAG, [AS], FTHG, HST, FTR FROM matches
#              Date    Team Location    HS  AST  FTAG    AS  FTHG  HST FTR
# 378127 2020-10-31  Zwolle     Away   8.0  5.0   1.0  10.0   5.0  5.0   H
# 378252 2020-11-06  Zwolle     Away  10.0  1.0   2.0  12.0   2.0  6.0   D
# 188956 2020-11-21  Zwolle     Home  10.0  2.0   1.0   2.0   1.0  4.0   D
# 378801 2020-11-28  Zwolle     Away  11.0  6.0   2.0  13.0   2.0  2.0   D
# 189453 2020-12-05  Zwolle     Home  16.0  4.0   1.0  12.0   2.0  5.0   H

# %% [markdown]
# Restrict raw data to only include historical matches played by teams with new ferature data to be calculated

# %%
# restrict to only teams in the new matches df
df_raw = df_raw[df_raw.Team.isin(df_new_matches.Team.unique())]

# %% [markdown]
# Split the features into all / home / away for calc

# %% [markdown]
# ### 3ii. Construct Base Feat Cols e.g. GF

# %% [markdown]
# Before we create historical looking avgs we need to construct the cols we will avg over

# %%
# create map from feat_name to base_name to construction
# split out by All / Home / Away for sequential calc
col_map = create_col_map(feats, streak_length, avg_type)
all_feats, home_feats, away_feats = split_home_away_feats(col_map)

# %%
print("E.g. of entry in col_map --> {}: {}".format(list(col_map.keys())[0], list(col_map.values())[0]))
# Out:
# E.g. of entry in col_map --> AvgGF_3: {'GF': {'Home': 'FTHG', 'Away': 'FTAG'}}

# %% [markdown]
# Now compute the base cols which we will then avg over to create our features

# %%
# create base cols e.g. GF / GA for use to calc e.g. AvgGF_3
c_dict = {'All': all_feats, 'Home': home_feats, 'Away': away_feats}
for k, v in c_dict.items():
    if len(v) > 0:
        df_raw = create_base_feat_cols(df_raw, v, k)
    elif k == 'All':
        # if all feats blank then issue so report
        print('All features is blank - probably an error: {}'.format(v))

# %%
df_raw.tail(5)
# Out:
#              Date    Team Location    HS  AST  FTAG    AS  FTHG  HST FTR   GF  \
# 378127 2020-10-31  Zwolle     Away   8.0  5.0   1.0  10.0   5.0  5.0   H  1.0
# 378252 2020-11-06  Zwolle     Away  10.0  1.0   2.0  12.0   2.0  6.0   D  2.0
# 188956 2020-11-21  Zwolle     Home  10.0  2.0   1.0   2.0   1.0  4.0   D  1.0
# 378801 2020-11-28  Zwolle     Away  11.0  6.0   2.0  13.0   2.0  2.0   D  2.0
# 189453 2020-12-05  Zwolle     Home  16.0  4.0   1.0  12.0   2.0  5.0   H  2.0
#
#          GA    SF    SA  STF  STA  PPG  GFH  GAH   SFH   SAH  STFH  STAH  \
# 378127  5.0  10.0   8.0  5.0  5.0  0.0  1.0  5.0  10.0   8.0   5.0   5.0
# 378252  2.0  12.0  10.0  1.0  6.0  1.0  2.0  2.0  12.0  10.0   1.0   6.0
# 188956  1.0  10.0   2.0  4.0  2.0  1.0  1.0  1.0  10.0   2.0   4.0   2.0
# 378801  2.0  13.0  11.0  6.0  2.0  1.0  2.0  2.0  13.0  11.0   6.0   2.0
# 189453  1.0  16.0  12.0  5.0  4.0  3.0  2.0  1.0  16.0  12.0   5.0   4.0
#
#         PPGH  GFA  GAA   SFA   SAA  STFA  STAA  PPGA
# 378127   0.0  1.0  5.0  10.0   8.0   5.0   5.0   0.0
# 378252   1.0  2.0  2.0  12.0  10.0   1.0   6.0   1.0
# 188956   1.0  1.0  1.0  10.0   2.0   4.0   2.0   1.0
# 378801   1.0  2.0  2.0  13.0  11.0   6.0   2.0   1.0
# 189453   3.0  2.0  1.0  16.0  12.0   5.0   4.0   3.0

# %% [markdown]
# ### 3iii. Compute Features

# %% [markdown]
# Now we have the data we want, we need to compute the historical averages grouped by team

# %%
# compute feats
ft_dfs = {}
for k, v in c_dict.items():
    # if not all, then restrict data to only home/away games
    if k != 'All':
        df_r = df_raw[df_raw.Location == k]
        df_f = calc_rolling_avg(df_r, v, streak_length)
    else:
        df_f = calc_rolling_avg(df_raw, v, streak_length)
    # add to dict
    ft_dfs[k] = df_f

# %% [markdown]
# An example of what our output looks like for features relevant to 'All' games

# %%
ft_dfs['All'].tail()
# Out:
#              Date    Team Location   GF   GA    SF    SA  STF  STA  PPG  \
# 378127 2020-10-31  Zwolle     Away  1.0  5.0  10.0   8.0  5.0  5.0  0.0
# 378252 2020-11-06  Zwolle     Away  2.0  2.0  12.0  10.0  1.0  6.0  1.0
# 188956 2020-11-21  Zwolle     Home  1.0  1.0  10.0   2.0  4.0  2.0  1.0
# 378801 2020-11-28  Zwolle     Away  2.0  2.0  13.0  11.0  6.0  2.0  1.0
# 189453 2020-12-05  Zwolle     Home  2.0  1.0  16.0  12.0  5.0  4.0  3.0
#
#          AvgGF_3   AvgGA_3    AvgSF_3    AvgSA_3  AvgSTF_3  AvgSTA_3  AvgPPG_3
# 378127  0.666667  2.000000  17.000000  10.333333  5.000000  3.666667  0.666667
# 378252  1.000000  2.333333  14.000000  10.000000  3.333333  4.666667  0.666667
# 188956  1.333333  2.666667  10.666667   6.666667  3.333333  4.333333  0.666667
# 378801  1.666667  1.666667  11.666667   7.666667  3.666667  3.333333  1.000000
# 189453  1.666667  1.333333  13.000000   8.333333  5.000000  2.666667  1.666667

# %% [markdown]
# ### 3iv. Merge & Shift Feature Tables

# %% [markdown]
# We now have the following issues:
#  - We only have 'Home' and 'Away' relevant stats computed for Home and Away games respectively
#   - This means e.g. if AvgGFH_3 is helpful to predict a team's perf in their next Away fixture we haven't got it
#  - All features are not backward looking i.e. goals in the current match are used to compute the avg - not just historical matches

# %%
df_feats = merge_home_away(ft_dfs, all_feats, home_feats, away_feats, shift=True)

# %%
df_feats.tail(10)
# Out:
#              Date    Team Location   GF   GA    SF    SA  STF  STA  PPG  \
# 379112 2020-09-19  Zwolle     Away  1.0  1.0  14.0  13.0  4.0  3.0  1.0
# 379113 2020-09-26  Zwolle     Home  4.0  0.0  20.0   9.0  8.0  2.0  3.0
# 379114 2020-10-18  Zwolle     Home  0.0  3.0  12.0  12.0  3.0  5.0  0.0
# 379115 2020-10-21  Zwolle     Away  1.0  1.0  21.0  11.0  6.0  3.0  1.0
# 379116 2020-10-24  Zwolle     Home  0.0  0.0  20.0  12.0  4.0  3.0  1.0
# 379117 2020-10-31  Zwolle     Away  1.0  5.0  10.0   8.0  5.0  5.0  0.0
# 379118 2020-11-06  Zwolle     Away  2.0  2.0  12.0  10.0  1.0  6.0  1.0
# 379119 2020-11-21  Zwolle     Home  1.0  1.0  10.0   2.0  4.0  2.0  1.0
# 379120 2020-11-28  Zwolle     Away  2.0  2.0  13.0  11.0  6.0  2.0  1.0
# 379121 2020-12-05  Zwolle     Home  2.0  1.0  16.0  12.0  5.0  4.0  3.0
#
#          AvgGF_3   AvgGA_3    AvgSF_3    AvgSA_3  AvgSTF_3  AvgSTA_3  \
# 379112  1.666667  2.000000  15.000000  12.333333  5.666667  5.000000
# 379113  0.666667  1.333333  14.666667  11.666667  4.666667  3.666667
# 379114  1.666667  1.000000  17.000000  11.666667  5.666667  3.666667
# 379115  1.666667  1.333333  15.333333  11.333333  5.000000  3.333333
# 379116  1.666667  1.333333  17.666667  10.666667  5.666667  3.333333
# 379117  0.333333  1.333333  17.666667  11.666667  4.333333  3.666667
# 379118  0.666667  2.000000  17.000000  10.333333  5.000000  3.666667
# 379119  1.000000  2.333333  14.000000  10.000000  3.333333  4.666667
# 379120  1.333333  2.666667  10.666667   6.666667  3.333333  4.333333
# 379121  1.666667  1.666667  11.666667   7.666667  3.666667  3.333333
#
#         AvgPPG_3  GFH  GAH   SFH   SAH  STFH  STAH  PPGH  AvgGFH_3  AvgGAH_3  \
# 379112  1.333333  NaN  NaN   NaN   NaN   NaN   NaN   NaN  2.333333  3.000000
# 379113  0.666667  4.0  0.0  20.0   9.0   8.0   2.0   3.0  2.333333  3.000000
# 379114  1.333333  0.0  3.0  12.0  12.0   3.0   5.0   0.0  2.666667  1.666667
# 379115  1.333333  NaN  NaN   NaN   NaN   NaN   NaN   NaN  1.333333  1.666667
# 379116  1.333333  0.0  0.0  20.0  12.0   4.0   3.0   1.0  1.333333  1.666667
# 379117  0.666667  NaN  NaN   NaN   NaN   NaN   NaN   NaN  1.333333  1.000000
# 379118  0.666667  NaN  NaN   NaN   NaN   NaN   NaN   NaN  1.333333  1.000000
# 379119  0.666667  1.0  1.0  10.0   2.0   4.0   2.0   1.0  1.333333  1.000000
# 379120  0.666667  NaN  NaN   NaN   NaN   NaN   NaN   NaN  0.333333  1.333333
# 379121  1.000000  2.0  1.0  16.0  12.0   5.0   4.0   3.0  0.333333  1.333333
#
#          AvgSFH_3   AvgSAH_3  AvgSTFH_3  AvgSTAH_3  AvgPPGH_3  GFA  GAA   SFA  \
# 379112  13.666667  16.000000   5.000000   7.666667   1.000000  1.0  1.0  14.0
# 379113  13.666667  16.000000   5.000000   7.666667   1.000000  NaN  NaN   NaN
# 379114  17.333333  12.333333   6.666667   5.000000   2.000000  NaN  NaN   NaN
# 379115  16.333333  11.333333   5.333333   4.333333   1.000000  1.0  1.0  21.0
# 379116  16.333333  11.333333   5.333333   4.333333   1.000000  NaN  NaN   NaN
# 379117  17.333333  11.000000   5.000000   3.333333   1.333333  1.0  5.0  10.0
# 379118  17.333333  11.000000   5.000000   3.333333   1.333333  2.0  2.0  12.0
# 379119  17.333333  11.000000   5.000000   3.333333   1.333333  NaN  NaN   NaN
# 379120  14.000000   8.666667   3.666667   3.333333   0.666667  2.0  2.0  13.0
# 379121  14.000000   8.666667   3.666667   3.333333   0.666667  NaN  NaN   NaN
#
#          SAA  STFA  STAA  PPGA  AvgGFA_3  AvgGAA_3   AvgSFA_3   AvgSAA_3  \
# 379112  13.0   4.0   3.0   1.0  0.333333  1.000000  10.000000  12.666667
# 379113   NaN   NaN   NaN   NaN  0.666667  1.333333  12.000000  13.000000
# 379114   NaN   NaN   NaN   NaN  0.666667  1.333333  12.000000  13.000000
# 379115  11.0   6.0   3.0   1.0  0.666667  1.333333  12.000000  13.000000
# 379116   NaN   NaN   NaN   NaN  1.000000  1.000000  16.000000  11.000000
# 379117   8.0   5.0   5.0   0.0  1.000000  1.000000  16.000000  11.000000
# 379118  10.0   1.0   6.0   1.0  1.000000  2.333333  15.000000  10.666667
# 379119   NaN   NaN   NaN   NaN  1.333333  2.666667  14.333333   9.666667
# 379120  11.0   6.0   2.0   1.0  1.333333  2.666667  14.333333   9.666667
# 379121   NaN   NaN   NaN   NaN  1.666667  3.000000  11.666667   9.666667
#
#         AvgSTFA_3  AvgSTAA_3  AvgPPGA_3
# 379112   2.333333   4.000000   0.666667
# 379113   3.333333   4.666667   0.666667
# 379114   3.333333   4.666667   0.666667
# 379115   3.333333   4.666667   0.666667
# 379116   5.000000   2.666667   1.000000
# 379117   5.000000   2.666667   1.000000
# 379118   5.000000   3.666667   0.666667
# 379119   4.000000   4.666667   0.666667
# 379120   4.000000   4.666667   0.666667
# 379121   4.000000   4.333333   0.666667

# %% [markdown]
# ### 3v. Finalise Output

# %% [markdown]
# Now we just need to return only the cols we wish and only for the new matches

# %%
# now we have our correctly offset feats
# we need to select just the cols we need
id_cols = ['Date', 'Team'] + ['Location']
df_feats = df_feats[id_cols + list(col_map.keys())]
df_feats.tail(10)
# Out:
#              Date    Team Location   AvgGF_3   AvgGA_3  AvgGFH_3  AvgGAH_3  \
# 379112 2020-09-19  Zwolle     Away  1.666667  2.000000  2.333333  3.000000
# 379113 2020-09-26  Zwolle     Home  0.666667  1.333333  2.333333  3.000000
# 379114 2020-10-18  Zwolle     Home  1.666667  1.000000  2.666667  1.666667
# 379115 2020-10-21  Zwolle     Away  1.666667  1.333333  1.333333  1.666667
# 379116 2020-10-24  Zwolle     Home  1.666667  1.333333  1.333333  1.666667
# 379117 2020-10-31  Zwolle     Away  0.333333  1.333333  1.333333  1.000000
# 379118 2020-11-06  Zwolle     Away  0.666667  2.000000  1.333333  1.000000
# 379119 2020-11-21  Zwolle     Home  1.000000  2.333333  1.333333  1.000000
# 379120 2020-11-28  Zwolle     Away  1.333333  2.666667  0.333333  1.333333
# 379121 2020-12-05  Zwolle     Home  1.666667  1.666667  0.333333  1.333333
#
#         AvgGFA_3  AvgGAA_3    AvgSF_3    AvgSA_3   AvgSFH_3   AvgSAH_3  \
# 379112  0.333333  1.000000  15.000000  12.333333  13.666667  16.000000
# 379113  0.666667  1.333333  14.666667  11.666667  13.666667  16.000000
# 379114  0.666667  1.333333  17.000000  11.666667  17.333333  12.333333
# 379115  0.666667  1.333333  15.333333  11.333333  16.333333  11.333333
# 379116  1.000000  1.000000  17.666667  10.666667  16.333333  11.333333
# 379117  1.000000  1.000000  17.666667  11.666667  17.333333  11.000000
# 379118  1.000000  2.333333  17.000000  10.333333  17.333333  11.000000
# 379119  1.333333  2.666667  14.000000  10.000000  17.333333  11.000000
# 379120  1.333333  2.666667  10.666667   6.666667  14.000000   8.666667
# 379121  1.666667  3.000000  11.666667   7.666667  14.000000   8.666667
#
#          AvgSFA_3   AvgSAA_3  AvgSTF_3  AvgSTA_3  AvgSTFH_3  AvgSTAH_3  \
# 379112  10.000000  12.666667  5.666667  5.000000   5.000000   7.666667
# 379113  12.000000  13.000000  4.666667  3.666667   5.000000   7.666667
# 379114  12.000000  13.000000  5.666667  3.666667   6.666667   5.000000
# 379115  12.000000  13.000000  5.000000  3.333333   5.333333   4.333333
# 379116  16.000000  11.000000  5.666667  3.333333   5.333333   4.333333
# 379117  16.000000  11.000000  4.333333  3.666667   5.000000   3.333333
# 379118  15.000000  10.666667  5.000000  3.666667   5.000000   3.333333
# 379119  14.333333   9.666667  3.333333  4.666667   5.000000   3.333333
# 379120  14.333333   9.666667  3.333333  4.333333   3.666667   3.333333
# 379121  11.666667   9.666667  3.666667  3.333333   3.666667   3.333333
#
#         AvgSTFA_3  AvgSTAA_3  AvgPPG_3  AvgPPGH_3  AvgPPGA_3
# 379112   2.333333   4.000000  1.333333   1.000000   0.666667
# 379113   3.333333   4.666667  0.666667   1.000000   0.666667
# 379114   3.333333   4.666667  1.333333   2.000000   0.666667
# 379115   3.333333   4.666667  1.333333   1.000000   0.666667
# 379116   5.000000   2.666667  1.333333   1.000000   1.000000
# 379117   5.000000   2.666667  0.666667   1.333333   1.000000
# 379118   5.000000   3.666667  0.666667   1.333333   0.666667
# 379119   4.000000   4.666667  0.666667   1.333333   0.666667
# 379120   4.000000   4.666667  0.666667   0.666667   0.666667
# 379121   4.000000   4.333333  1.000000   0.666667   0.666667

# %% [markdown]
# Left join onto our original match data - this will also provide a few additional ID columns to help select subsets of data

# %%
df_final = pd.merge(left=df_new_matches, right=df_feats, how='left', on=id_cols)

# %%
df_final.tail(10)
# Out:
#              Date                Team Location      Country  Div Season  \
# 379112 2020-12-06           Tottenham     Home      england   E0   2021
# 379113 2020-12-06             Utrecht     Home  netherlands   N1   2021
# 379114 2020-12-06              Verona     Home        italy   I1   2021
# 379115 2020-12-06             Vicenza     Home        italy   I2   2021
# 379116 2020-12-06          Villarreal     Home        spain  SP1   2021
# 379117 2020-12-06       Werder Bremen     Home      germany   D1   2021
# 379118 2020-12-06           West Brom     Home      england   E0   2021
# 379119 2020-12-06              Wolves     Away      england   E0   2021
# 379120 2020-12-06  Wurzburger Kickers     Home      germany   D2   2021
# 379121 2020-12-06            Zaragoza     Home        spain  SP2   2021
#
#          AvgGF_3   AvgGA_3  AvgGFH_3  AvgGAH_3  AvgGFA_3  AvgGAA_3    AvgSF_3  \
# 379112  1.000000  0.000000  2.333333  1.333333  0.666667  0.000000   9.333333
# 379113  0.666667  1.666667  1.000000  1.666667  1.000000  2.000000   7.666667
# 379114  1.333333  1.333333  1.000000  1.000000  1.666667  1.000000   8.333333
# 379115  1.333333  1.000000  2.000000  2.000000  1.333333  1.000000  13.000000
# 379116  1.666667  1.000000  1.666667  0.666667  1.333333  0.666667  10.666667
# 379117  1.666667  2.333333  1.000000  0.666667  1.666667  2.333333  10.666667
# 379118  0.333333  0.666667  0.333333  0.333333  0.333333  1.333333  12.000000
# 379119  1.000000  1.000000  1.333333  0.666667  1.000000  0.666667  12.666667
# 379120  1.333333  2.333333  1.333333  2.000000  1.000000  3.000000  10.666667
# 379121  0.333333  1.666667  1.333333  2.000000  0.333333  1.666667   9.000000
#
#           AvgSA_3   AvgSFH_3   AvgSAH_3   AvgSFA_3   AvgSAA_3  AvgSTF_3  \
# 379112  15.666667   8.000000  13.666667  11.000000  12.666667  2.666667
# 379113  12.666667  18.333333  12.666667   9.333333  11.333333  3.666667
# 379114  15.333333  13.666667   8.333333   5.666667  17.333333  4.333333
# 379115  14.333333  17.000000  10.333333  13.000000  14.333333  4.000000
# 379116   9.000000  13.333333   9.333333   8.666667   8.666667  2.666667
# 379117  11.666667  10.000000  11.000000   7.666667  13.666667  4.000000
# 379118  19.000000  14.000000  16.333333   8.666667  11.666667  3.333333
# 379119  10.000000  17.000000   7.666667   8.333333  12.000000  5.333333
# 379120  12.333333  11.333333   7.000000   9.666667  17.666667  4.000000
# 379121  11.333333  10.666667   7.000000   7.666667  11.333333  2.000000
#
#         AvgSTA_3  AvgSTFH_3  AvgSTAH_3  AvgSTFA_3  AvgSTAA_3  AvgPPG_3  \
# 379112  3.333333   3.666667   3.666667   3.000000   3.000000  2.333333
# 379113  4.000000   4.333333   4.000000   4.666667   4.333333  0.666667
# 379114  6.666667   8.666667   4.000000   2.666667   7.666667  1.333333
# 379115  3.666667   5.000000   4.000000   4.000000   3.666667  1.666667
# 379116  3.333333   4.000000   1.666667   3.000000   3.000000  1.666667
# 379117  3.333333   2.666667   4.000000   4.000000   4.666667  0.666667
# 379118  5.666667   4.666667   4.666667   2.000000   5.333333  1.000000
# 379119  2.333333   5.666667   2.000000   3.333333   2.333333  1.333333
# 379120  6.333333   4.333333   2.666667   2.333333   6.333333  1.000000
# 379121  3.666667   4.000000   4.666667   2.000000   3.000000  0.000000
#
#         AvgPPGH_3  AvgPPGA_3
# 379112   2.333333   2.333333
# 379113   1.333333   0.666667
# 379114   1.333333   1.666667
# 379115   1.000000   1.666667
# 379116   2.333333   1.666667
# 379117   1.666667   0.666667
# 379118   1.333333   0.333333
# 379119   1.666667   2.000000
# 379120   1.000000   0.000000
# 379121   0.333333   0.000000

# %% [markdown]
# ### 3vi. Check

# %% [markdown]
# Can do a few checks to verify if the feature data is in line with expectations

# %%
t = ['Man United', 'Tottenham', 'Man City', 'West Brom', 'Wolves']

# %%
df_check = df_raw[df_raw.Team.isin(t)][['Date', 'Team', 'GF', 'GA']]

# %%
df_check = df_check[['GF', 'GA']].groupby(df_check['Team']).rolling(streak_length).mean().shift(1)

# %%
df_data = df_final[df_final.Team.isin(t)].sort_values(['Team', 'Date'])[['AvgGF_3', 'AvgGA_3']]

# %%
df_check
# Out:
#                        GF        GA
# Team
# Man City 112          NaN       NaN
#          189727       NaN       NaN
#          189742       NaN       NaN
#          237     0.333333  1.000000
#          257     0.000000  1.333333
# ...                   ...       ...
# Wolves   188470  1.000000  0.333333
#          378379  1.333333  0.333333
#          189082  1.000000  0.666667
#          378818  1.000000  0.666667
#          379080  1.000000  1.000000
#
# [5438 rows x 2 columns]

# %%
x = df_check['GA'].values
y = df_data['AvgGA_3'].values

# %%
len(x)
# Out:
# 5438

# %%
len(y)
# Out:
# 5438

# %%
sum(np.nan_to_num(x) == np.nan_to_num(y))
# Out:
# 5430

# %% [markdown]
# ## 4. Set Down Into Features Table

# %% [markdown]
# Once we have calculated the features we need to set them down into the sqlite db

# %%
df = handle_feats(feat_list)
# Out:
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='features'
# Features table doesn't exist
# Running query: SELECT Date, HomeTeam, AwayTeam, Country, Div, Season FROM matches
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='matches'
# Running query: SELECT Date, HomeTeam, AwayTeam, FTAG, FTR, HST, AST, HS, [AS], FTHG FROM matches
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='matches'
# Running query: SELECT Date, HomeTeam, AwayTeam, FTAG, FTR, HST, AST, HS, [AS], FTHG FROM matches
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='matches'
# Running query: SELECT Date, HomeTeam, AwayTeam, FTAG, FTR, HST, AST, HS, [AS], FTHG FROM matches
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='matches'
# Running query: SELECT Date, HomeTeam, AwayTeam, FTAG, FTR, HST, AST, HS, [AS], FTHG FROM matches
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='matches'
# Running query: SELECT Date, HomeTeam, AwayTeam, FTAG, FTR, HST, AST, HS, [AS], FTHG FROM matches

# %%
res = process_feature_data(feat_list, uat=False)
# Out:
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='features'
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='features'
# Running query: SELECT name FROM sqlite_master WHERE type='table' AND name='features'
# Running query: SELECT Date, Team FROM features
# Running query: SELECT Date, HomeTeam, AwayTeam, Country, Div, Season FROM matches
# No new matches to process features for
# Exiting feature processing
